# %% [markdown]
# <a href="https://colab.research.google.com/github/26417-star/10717/blob/main/2060901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#임빈 실행결과를 참고하여 특정날짜를 입력하면 오늘부터 며칠이 남았는지를 계산하여 출력하는 디데이(D-day)
#작성해보자
#사용자로부터 연,월,일을 숫자 형태로 입력하기
from datetime import datetime, date, time

year = int(input('입력하세요'))
month = int(input(' 입력하세요'))
day = int (input(' 입력하세요'))
dt4 = date(year, month, day)
print(dt4)
