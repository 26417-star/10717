# %% [markdown]
# <a href="https://colab.research.google.com/github/26417-star/10717/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2026 9월 10일
a ='hello'
b ='world'
print(a+b)
print(a*3)
print(a<b)
# Out:
# helloworld
# hellohellohello
# True

# %%
주민등록번호 = input("100626")
연 = 주민등록번호[0:2]
월 = 주민등록번호[2:4]
일 = 주민등록번호[4:6]
print(연)
print(월)
print(일)
# Out:
# 100626100626
# 10
# 06
# 26

# %%
# 한 문자만 인덱싱 : 변수명(인덱스변호)
a = 'hello python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# h
# p
# n

# %%
#연속된 부분의 문자열을 슬라이싱 : 변수명(시작인데스 : 종료인덱스)
a = 'hello python'
print(a[0:5])        # 0 ~ 4
print(a[6:])         # 6 ~ 끝
print(a[:5])         # 0 ~ 4
print(a[6:-4])       # 6 ~ 끝에서 5번째
print(a[0:9:2])      # 0 ~ 8(2간격)
# Out:
# hello
# python
# hello
# py
# hlopt
